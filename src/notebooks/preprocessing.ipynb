# %%
import subprocess
import re
from pathlib import Path

import pandas as pd

# %%
GIT_ROOT = subprocess.check_output(['git', 'rev-parse', '--show-toplevel'])
GIT_ROOT = Path(GIT_ROOT.decode('utf-8').strip())
DATA = GIT_ROOT / Path('data')
SWITZERLAND_DATASET = DATA / Path('switzerland.data')
HUNGARIAN_DATASET = DATA / Path('hungarian.data')
LONG_BEACH_DATASET = DATA / Path('long-beach-va.data')
ATTRIBUTES_FILE = DATA / Path('attribute_names')
ATTRIBUTES_OF_INTEREST = ['age', 'sex', 'cp', 'thalrest', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'smoke', 'cigs', 'years', 'famhist', 'num']

# %%
with ATTRIBUTES_FILE.open() as attributes_fp:
    attributes = attributes_fp.read().split(', ')

# %%
def load_dataset(path):
    with path.open() as dataset_fp:
        raw_data = dataset_fp.read()
        
    samples = []
    current_sample = []
    for count, data_point in enumerate(re.split(r'\s+', raw_data)):
        if count != 0 and count % len(attributes) == 0:
            samples.append(current_sample)
            current_sample = []
            
        if data_point == '-9':
            data_point = 'NaN'
            
        current_sample.append(data_point)
        
    dataset = pd.DataFrame(data=samples, columns=attributes)
    return dataset

# %%
switzerland_dataset = load_dataset(SWITZERLAND_DATASET)
switzerland_dataset
# Out:
#        id ccf age sex painloc painexer relrest pncaden cp trestbps  ...  \
# 0    3001   0  65   1       1        1       1     NaN  4      115  ...
# 1    3002   0  32   1       0        0       0     NaN  1       95  ...
# 2    3003   0  61   1       1        1       1     NaN  4      105  ...
# 3    3004   0  50   1       1        1       1     NaN  4      145  ...
# 4    3005   0  57   1       1        1       1     NaN  4      110  ...
# ..    ...  ..  ..  ..     ...      ...     ...     ... ..      ...  ...
# 118  4070   0  54   1       1        1       1     NaN  4      180  ...
# 119  4071   0  56   1       1        1       1     NaN  4      125  ...
# 120  4072   0  56   1       0        1       1     NaN  3      125  ...
# 121  4073   0  54   1       1        1       1     NaN  4      130  ...
# 122  4074   0  66   0       1        1       1     NaN  4      155  ...
#
#     rcaprox rcadist lvx1 lvx2 lvx3 lvx4 lvf cathef junk  name
# 0         1       1    1    1    1    1   1     75  -9.  name
# 1         1       1    1    1    1    5   1     63  -9.  name
# 2         2       1    1    1    1    1   1     67  -9.  name
# 3         1       1    1    1    1    5   4     36  -9.  name
# 4         2       1    1    1    1    1   1     60  -9.  name
# ..      ...     ...  ...  ...  ...  ...  ..    ...  ...   ...
# 118       1       1    1    1    1    1   1     71  -9.  name
# 119       2       1    5    1    1    1   2     68  -9.  name
# 120       1       1    1    1    5    3   2     61  -9.  name
# 121       2       1    1    1    1    1   1    -9.  -9.  name
# 122       2       1    1    1    1    1   1     70  -9.  name
#
# [123 rows x 76 columns]

# %%
switzerland_dataset[ATTRIBUTES_OF_INTEREST]
# Out:
#     age sex cp thalrest trestbps chol  fbs restecg thalach exang oldpeak  \
# 0    65   1  4       56      115    0    0       0      93     1       0
# 1    32   1  1       74       95    0  NaN       0     127     0     0.7
# 2    61   1  4       70      105    0  NaN       0     110     1     1.5
# 3    50   1  4       82      145    0  NaN       0     139     1     0.7
# 4    57   1  4       71      110    0  NaN       1     131     1     1.4
# ..   ..  .. ..      ...      ...  ...  ...     ...     ...   ...     ...
# 118  54   1  4       58      180    0  NaN       0     150     0     1.5
# 119  56   1  4       55      125    0    1       0     103     1       1
# 120  56   1  3       64      125    0  NaN       0      98     0      -2
# 121  54   1  4       58      130    0  NaN       0     110     1       3
# 122  66   0  4       66      155    0  NaN       0      90     0       0
#
#     slope smoke cigs years famhist num
# 0       2   NaN  NaN   NaN     NaN   1
# 1       1     1  NaN   NaN     NaN   1
# 2       1   NaN  NaN   NaN     NaN   1
# 3       2   NaN  NaN   NaN     NaN   1
# 4       1   NaN  NaN   NaN     NaN   3
# ..    ...   ...  ...   ...     ...  ..
# 118     2   NaN  NaN   NaN     NaN   1
# 119     2     1  NaN   NaN     NaN   3
# 120     2   NaN  NaN   NaN     NaN   2
# 121     2   NaN  NaN   NaN     NaN   3
# 122   NaN   NaN  NaN   NaN     NaN   1
#
# [123 rows x 17 columns]

# %%
hungarian_dataset = load_dataset(HUNGARIAN_DATASET)
hungarian_dataset
# Out:
#        id ccf age sex painloc painexer relrest pncaden cp trestbps  ...  \
# 0    1254   0  40   1       1        0       0     NaN  2      140  ...
# 1    1255   0  49   0       1        0       0     NaN  3      160  ...
# 2    1256   0  37   1       1        0       0     NaN  2      130  ...
# 3    1257   0  48   0       1        1       1     NaN  4      138  ...
# 4    1258   0  54   1       1        0       1     NaN  3      150  ...
# ..    ...  ..  ..  ..     ...      ...     ...     ... ..      ...  ...
# 289  1053   0  48   0       0        0       0     NaN  2      NaN  ...
# 290  1054   0  36   1       1        0       0     NaN  2      120  ...
# 291  5001   0  48   1       0        0       0     NaN  3      110  ...
# 292  5000   0  47   0       0        0       0     NaN  2      140  ...
# 293  5002   0  53   1       1        1       1     NaN  4      130  ...
#
#     rcaprox rcadist lvx1 lvx2 lvx3 lvx4 lvf cathef junk  name
# 0       NaN     NaN    1    1    1    1   1    -9.  -9.  name
# 1       NaN     NaN    1    1    1    1   1    -9.  -9.  name
# 2       NaN     NaN    1    1    1    1   1    -9.  -9.  name
# 3         2     NaN    1    1    1    1   1    -9.  -9.  name
# 4         1     NaN    1    1    1    1   1    -9.  -9.  name
# ..      ...     ...  ...  ...  ...  ...  ..    ...  ...   ...
# 289     NaN     NaN    1    1    1    1   1    -9.  -9.  name
# 290     NaN     NaN    1    1    1    1   1    -9.  -9.  name
# 291     NaN     NaN    1    1    1    1   1    -9.  -9.  name
# 292     NaN     NaN    1    1    1    1   1    -9.  -9.  name
# 293       1       1    1    1    1    1   1    -9.  -9.  name
#
# [294 rows x 76 columns]

# %%
hungarian_dataset[ATTRIBUTES_OF_INTEREST]
# Out:
#     age sex cp thalrest trestbps chol fbs restecg thalach exang oldpeak slope  \
# 0    40   1  2       86      140  289   0       0     172     0       0   NaN
# 1    49   0  3      100      160  180   0       0     156     0       1     2
# 2    37   1  2       58      130  283   0       1      98     0       0   NaN
# 3    48   0  4       54      138  214   0       0     108     1     1.5     2
# 4    54   1  3       74      150  NaN   0       0     122     0       0   NaN
# ..   ..  .. ..      ...      ...  ...  ..     ...     ...   ...     ...   ...
# 289  48   0  2      NaN      NaN  308   0       1     NaN   NaN       2     1
# 290  36   1  2       72      120  166   0       0     180     0       0   NaN
# 291  48   1  3       66      110  211   0       0     138     0       0   NaN
# 292  47   0  2       84      140  257   0       0     135     0       1     1
# 293  53   1  4       80      130  182   0       0     148     0       0   NaN
#
#     smoke cigs years famhist num
# 0     NaN  NaN   NaN     NaN   0
# 1     NaN  NaN   NaN     NaN   1
# 2     NaN  NaN   NaN     NaN   0
# 3     NaN  NaN   NaN     NaN   3
# 4     NaN  NaN   NaN     NaN   0
# ..    ...  ...   ...     ...  ..
# 289   NaN  NaN   NaN     NaN   0
# 290   NaN  NaN   NaN     NaN   0
# 291   NaN  NaN   NaN     NaN   0
# 292   NaN  NaN   NaN     NaN   0
# 293   NaN  NaN   NaN     NaN   0
#
# [294 rows x 17 columns]

# %%
long_beach_dataset = load_dataset(LONG_BEACH_DATASET)
long_beach_dataset
# Out:
#       id ccf age sex painloc painexer relrest pncaden cp trestbps  ...  \
# 0      1   0  63   1       1        1       1     NaN  4      140  ...
# 1      2   0  44   1       1        1       1     NaN  4      130  ...
# 2      3   0  60   1       1        1       1     NaN  4      132  ...
# 3      4   0  55   1       1        1       1     NaN  4      142  ...
# 4      5   0  66   1       1        0       0     NaN  3      110  ...
# ..   ...  ..  ..  ..     ...      ...     ...     ... ..      ...  ...
# 195  200   0  54   0       1        1       1     NaN  4      127  ...
# 196  201   0  62   1       0        0       0     NaN  1      NaN  ...
# 197  202   0  55   1       1        1       1     NaN  4      122  ...
# 198  116   0  58   1       1        1       1     NaN  4      NaN  ...
# 199  160   0  62   1       1        0       0     NaN  2      120  ...
#
#     rcaprox rcadist lvx1 lvx2 lvx3 lvx4 lvf cathef junk  name
# 0         2       1    1    1    1    1   1    0.7  5.5  name
# 1         1       1    1    1    1    1   1    0.5  -9.  name
# 2         2       1    1    1    1    7   2   0.52  4.1  name
# 3         1       1    1    1    1    1   1   0.73  6.5  name
# 4         1       1    1    1    1    1   1   0.73    8  name
# ..      ...     ...  ...  ...  ...  ...  ..    ...  ...   ...
# 195       1       1    1    1    1    1   1   0.76  5.6  name
# 196       1       1    1    1    1    1   2   0.62  3.5  name
# 197       2       1    1    1    1    1   1   0.69  5.6  name
# 198       1       1    1    1    1    1   1   0.81    6  name
# 199       2       1    1    1    1    1   1    NaN  -9.  name
#
# [200 rows x 76 columns]

# %%
long_beach_dataset[ATTRIBUTES_OF_INTEREST]
# Out:
#     age sex cp thalrest trestbps chol fbs restecg thalach exang oldpeak slope  \
# 0    63   1  4       62      140  260   0       1     112     1       3     2
# 1    44   1  4       73      130  209   0       1     127     0       0   NaN
# 2    60   1  4       68      132  218   0       1     140     1     1.5     3
# 3    55   1  4       60      142  228   0       1     149     1     2.5     1
# 4    66   1  3       66      110  213   1       2      99     1     1.3     2
# ..   ..  .. ..      ...      ...  ...  ..     ...     ...   ...     ...   ...
# 195  54   0  4       83      127  333   1       1     154     0       0   NaN
# 196  62   1  1      NaN      NaN  139   0       1     NaN   NaN     NaN   NaN
# 197  55   1  4       74      122  223   1       1     100     0       0   NaN
# 198  58   1  4      NaN      NaN  385   1       2     NaN   NaN     NaN   NaN
# 199  62   1  2       67      120  254   0       2      93     1       0   NaN
#
#     smoke cigs years famhist num
# 0       0    0     0       0   2
# 1       0   20    10       0   0
# 2       1   40    40       0   2
# 3       1   20    30       0   1
# 4       0   20     8       1   0
# ..    ...  ...   ...     ...  ..
# 195     0    0     0       1   1
# 196     1   15    30       0   0
# 197     1   20    40       0   2
# 198     0   10    20       1   0
# 199     0    0     0       0   1
#
# [200 rows x 17 columns]
