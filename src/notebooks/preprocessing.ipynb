# %%
import subprocess
import re
from pathlib import Path

import pandas as pd

# %%
GIT_ROOT = subprocess.check_output(['git', 'rev-parse', '--show-toplevel'])
GIT_ROOT = Path(GIT_ROOT.decode('utf-8').strip())
BUILD = GIT_ROOT / Path('build')
DATA = GIT_ROOT / Path('data')
SWITZERLAND_DATASET = DATA / Path('switzerland.data')
HUNGARIAN_DATASET = DATA / Path('hungarian.data')
LONG_BEACH_DATASET = DATA / Path('long_beach.data')
ATTRIBUTES_FILE = DATA / Path('attribute_names')
SHUFFLED_DATASET_OUTPUT_PATH = BUILD / Path('combined_data.csv')
ATTRIBUTES_OF_INTEREST = ['age', 'sex', 'cp', 'thalrest', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'smoke', 'cigs', 'years', 'famhist', 'num']

# %%
with ATTRIBUTES_FILE.open() as attributes_fp:
    attributes = attributes_fp.read().split(', ')

# %%
def load_dataset(path):
    with path.open() as dataset_fp:
        raw_data = dataset_fp.read()
        
    samples = []
    current_sample = []
    for count, data_point in enumerate(re.split(r'\s+', raw_data)):
        if count != 0 and count % len(attributes) == 0:
            samples.append(current_sample)
            current_sample = []
            
        if data_point == '-9':
            data_point = None
            
        current_sample.append(data_point)
        
    dataset = pd.DataFrame(data=samples, columns=attributes)
    return dataset

# %%
def save_with_suffix(dataset, path, suffix):
    modified_path = path.with_name(path.stem + suffix)
    dataset.to_csv(modified_path, index=None)

# %%
switzerland_dataset = load_dataset(SWITZERLAND_DATASET)
curated_switzerland_dataset = switzerland_dataset[ATTRIBUTES_OF_INTEREST]
curated_switzerland_dataset
# Out:
#     age sex cp thalrest trestbps chol   fbs restecg thalach exang oldpeak  \
# 0    65   1  4       56      115    0     0       0      93     1       0
# 1    32   1  1       74       95    0  None       0     127     0     0.7
# 2    61   1  4       70      105    0  None       0     110     1     1.5
# 3    50   1  4       82      145    0  None       0     139     1     0.7
# 4    57   1  4       71      110    0  None       1     131     1     1.4
# ..   ..  .. ..      ...      ...  ...   ...     ...     ...   ...     ...
# 118  54   1  4       58      180    0  None       0     150     0     1.5
# 119  56   1  4       55      125    0     1       0     103     1       1
# 120  56   1  3       64      125    0  None       0      98     0      -2
# 121  54   1  4       58      130    0  None       0     110     1       3
# 122  66   0  4       66      155    0  None       0      90     0       0
#
#     slope smoke  cigs years famhist num
# 0       2  None  None  None    None   1
# 1       1     1  None  None    None   1
# 2       1  None  None  None    None   1
# 3       2  None  None  None    None   1
# 4       1  None  None  None    None   3
# ..    ...   ...   ...   ...     ...  ..
# 118     2  None  None  None    None   1
# 119     2     1  None  None    None   3
# 120     2  None  None  None    None   2
# 121     2  None  None  None    None   3
# 122  None  None  None  None    None   1
#
# [123 rows x 17 columns]

# %%
hungarian_dataset = load_dataset(HUNGARIAN_DATASET)
curated_hungarian_dataset = hungarian_dataset[ATTRIBUTES_OF_INTEREST]
curated_hungarian_dataset
# Out:
#     age sex cp thalrest trestbps  chol fbs restecg thalach exang oldpeak  \
# 0    40   1  2       86      140   289   0       0     172     0       0
# 1    49   0  3      100      160   180   0       0     156     0       1
# 2    37   1  2       58      130   283   0       1      98     0       0
# 3    48   0  4       54      138   214   0       0     108     1     1.5
# 4    54   1  3       74      150  None   0       0     122     0       0
# ..   ..  .. ..      ...      ...   ...  ..     ...     ...   ...     ...
# 289  48   0  2     None     None   308   0       1    None  None       2
# 290  36   1  2       72      120   166   0       0     180     0       0
# 291  48   1  3       66      110   211   0       0     138     0       0
# 292  47   0  2       84      140   257   0       0     135     0       1
# 293  53   1  4       80      130   182   0       0     148     0       0
#
#     slope smoke  cigs years famhist num
# 0    None  None  None  None    None   0
# 1       2  None  None  None    None   1
# 2    None  None  None  None    None   0
# 3       2  None  None  None    None   3
# 4    None  None  None  None    None   0
# ..    ...   ...   ...   ...     ...  ..
# 289     1  None  None  None    None   0
# 290  None  None  None  None    None   0
# 291  None  None  None  None    None   0
# 292     1  None  None  None    None   0
# 293  None  None  None  None    None   0
#
# [294 rows x 17 columns]

# %%
long_beach_dataset = load_dataset(LONG_BEACH_DATASET)
curated_long_beach_dataset = long_beach_dataset[ATTRIBUTES_OF_INTEREST]
curated_long_beach_dataset
# Out:
#     age sex cp thalrest trestbps chol fbs restecg thalach exang oldpeak slope  \
# 0    63   1  4       62      140  260   0       1     112     1       3     2
# 1    44   1  4       73      130  209   0       1     127     0       0  None
# 2    60   1  4       68      132  218   0       1     140     1     1.5     3
# 3    55   1  4       60      142  228   0       1     149     1     2.5     1
# 4    66   1  3       66      110  213   1       2      99     1     1.3     2
# ..   ..  .. ..      ...      ...  ...  ..     ...     ...   ...     ...   ...
# 195  54   0  4       83      127  333   1       1     154     0       0  None
# 196  62   1  1     None     None  139   0       1    None  None    None  None
# 197  55   1  4       74      122  223   1       1     100     0       0  None
# 198  58   1  4     None     None  385   1       2    None  None    None  None
# 199  62   1  2       67      120  254   0       2      93     1       0  None
#
#     smoke cigs years famhist num
# 0       0    0     0       0   2
# 1       0   20    10       0   0
# 2       1   40    40       0   2
# 3       1   20    30       0   1
# 4       0   20     8       1   0
# ..    ...  ...   ...     ...  ..
# 195     0    0     0       1   1
# 196     1   15    30       0   0
# 197     1   20    40       0   2
# 198     0   10    20       1   0
# 199     0    0     0       0   1
#
# [200 rows x 17 columns]

# %%
combined_dataset = curated_switzerland_dataset.append(curated_hungarian_dataset).append(curated_long_beach_dataset)
shuffled_dataset = combined_dataset.sample(frac=1)
shuffled_dataset
# Out:
#     age sex cp thalrest trestbps chol   fbs restecg thalach exang oldpeak  \
# 123  57   1  4       77      110  197     0       2     100     0       0
# 196  62   1  1     None     None  139     0       1    None  None    None
# 51   47   0  4       74      120  205     0       0      98     1       2
# 176  43   1  4       58      140  288     0       0     135     1       2
# 71   44   1  2       82      130  215     0       0     135     0       0
# ..   ..  .. ..      ...      ...  ...   ...     ...     ...   ...     ...
# 63   56   1  3       59      170    0     0       2     123     1     2.5
# 30   62   1  4       60      115    0  None       0     128     1     2.5
# 116  53   1  3       91      160    0  None       2     122     1       0
# 136  43   0  2      100      120  215     0       1     175     0       0
# 61   61   1  4       76      110    0  None       0     108     1       2
#
#     slope smoke  cigs years famhist num
# 123  None     0    30    40       1   0
# 196  None     1    15    30       0   0
# 51      2  None  None  None    None   4
# 176     2  None  None  None    None   4
# 71   None  None  None  None    None   0
# ..    ...   ...   ...   ...     ...  ..
# 63   None     1    20     2    None   4
# 30      3  None  None  None    None   2
# 116  None  None  None  None    None   1
# 136  None  None  None  None    None   0
# 61      3     1  None  None       0   2
#
# [617 rows x 17 columns]

# %%
shuffled_dataset.to_csv(str(SHUFFLED_DATASET_OUTPUT_PATH), index=False)
